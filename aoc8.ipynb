# %%
# Read the file and convert it into a matrix
with open('aoc8.txt', 'r') as file:
    map_matrix = [list(line.strip()) for line in file]

# Display the matrix
for row in map_matrix:
    print(row)
# Out:
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '6', '.', 'b', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '6', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '8', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', 'Y', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', 'o', '.', '.', '.', '.', '.', '.', '.']
# ...

# %%
# Function to find diffferent characters in the matrix and their positions, output a list containing the character and its position list
def find_char(matrix):
    char_list = []
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] not in [x[0] for x in char_list] and matrix[i][j] != '.':
                char_list.append([matrix[i][j], [(i, j)]])
            else:
                for x in char_list:
                    if x[0] == matrix[i][j]:
                        x[1].append((i, j))
    return char_list

char_position_list = find_char(map_matrix)

# %%
char_position_list
# Out:
# [['6', [(0, 11), (1, 8), (5, 9), (14, 20)]],
#  ['b', [(0, 13), (6, 18), (11, 10)]],
#  ['8', [(1, 25), (4, 12), (11, 18), (12, 19)]],
#  ['Y', [(2, 2), (13, 10), (14, 3), (15, 5)]],
#  ['o', [(2, 42), (16, 33), (19, 28), (29, 25)]],
#  ['V', [(3, 4), (8, 0), (10, 7), (21, 21)]],
#  ['j', [(3, 8), (5, 5), (6, 3), (12, 10)]],
#  ['B', [(3, 21), (14, 39), (20, 34), (25, 42)]],
#  ['c', [(3, 35), (5, 38), (8, 42), (10, 29)]],
#  ['X', [(4, 22), (7, 14), (14, 13), (15, 21)]],
#  ['L', [(4, 30), (5, 19), (13, 26)]],
#  ['v', [(5, 8), (8, 15), (11, 13), (24, 18)]],
#  ['3', [(5, 17), (6, 10), (9, 14), (10, 15)]],
#  ['M', [(6, 2), (7, 10), (11, 15), (28, 29)]],
#  ['p', [(6, 9), (8, 22), (19, 23), (21, 28)]],
#  ['Z', [(6, 27), (8, 32), (13, 30), (23, 21)]],
#  ['J', [(6, 48), (12, 41), (23, 35), (25, 38)]],
#  ['U', [(10, 14), (11, 17), (16, 9), (17, 24)]],
#  ['q', [(13, 17), (24, 26), (31, 24), (32, 25)]],
#  ['H', [(13, 27), (16, 34), (21, 36)]],
# ...

# %%
# Function to find all positions of characters that are not ".", return a list of positions
def find_all_char_pos(matrix):
    char_pos = []
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] != '.':
                char_pos.append((i, j))
    return char_pos

all_char_pos_list = find_all_char_pos(map_matrix)

# %%
all_char_pos_list
# Out:
# [(0, 11),
#  (0, 13),
#  (1, 8),
#  (1, 25),
#  (2, 2),
#  (2, 42),
#  (3, 4),
#  (3, 8),
#  (3, 21),
#  (3, 35),
#  (4, 12),
#  (4, 22),
#  (4, 30),
#  (5, 5),
#  (5, 8),
#  (5, 9),
#  (5, 17),
#  (5, 19),
#  (5, 38),
#  (6, 2),
#  (6, 3),
#  (6, 9),
#  (6, 10),
#  (6, 18),
#  (6, 27),
#  (6, 48),
#  (7, 10),
#  (7, 14),
#  (8, 0),
#  (8, 15),
#  (8, 22),
#  (8, 32),
#  (8, 42),
#  (9, 14),
#  (10, 7),
#  (10, 14),
#  (10, 15),
#  (10, 29),
#  (11, 10),
#  (11, 13),
#  (11, 15),
#  (11, 17),
#  (11, 18),
#  (12, 10),
#  (12, 19),
#  (12, 41),
#  (13, 10),
#  (13, 17),
#  (13, 26),
#  (13, 27),
#  (13, 30),
#  (13, 34),
#  (13, 46),
#  (14, 2),
#  (14, 3),
#  (14, 12),
#  (14, 13),
#  (14, 20),
#  (14, 39),
#  (14, 40),
#  (15, 3),
#  (15, 5),
#  (15, 21),
#  (15, 22),
#  (15, 34),
#  (16, 9),
#  (16, 17),
#  (16, 33),
#  (16, 34),
#  (16, 36),
#  (17, 0),
#  (17, 15),
#  (17, 24),
#  (18, 11),
#  (18, 26),
#  (18, 34),
#  (18, 38),
#  (18, 39),
#  (19, 19),
#  (19, 23),
# ...

# %%
# Function to find new points
def find_antinode(point1, point2, width, height):
    point1_x, point1_y = point1[0], point1[1]
    point2_x, point2_y = point2[0], point2[1]
    new_point_list = [
    (2 * point1_x - point2_x, 2 * point1_y - point2_y),
    (2 * point2_x - point1_x, 2 * point2_y - point1_y)
    ]
    """

    if abs(point1_x - point2_x) // 3 == 0 and abs(point1_y - point2_y) // 3 == 0:
        new_point_list.append((point1_x + (point2_x - point1_x) / 3, point1_y + (point2_y - point1_y) / 3))
        new_point_list.append((point2_x + (point1_x - point2_x) / 3, point2_y + (point1_y - point2_y) / 3))

    """
    for point in new_point_list:
        if point[0] < 0 or point[0] >= width or point[1] < 0 or point[1] >= height:
            new_point_list.remove(point)
    return new_point_list


find_antinode((0, 11), (1, 8), 50, 50)
# Out:
# [(2, 5)]

# %%
all_anitnode_list = []
for char in char_position_list:
    for i in range(len(char[1])):
        for j in range(i + 1, len(char[1])):
            all_anitnode_list.extend(find_antinode(char[1][i], char[1][j], len(map_matrix[0]), len(map_matrix)))

print(len(set(all_anitnode_list)))
# Out:
# 340

# %%
# Read the file and convert it into a matrix
with open('aoc8_test.txt', 'r') as file:
    test_map_matrix = [list(line.strip()) for line in file]

# Display the matrix
for row in test_map_matrix:
    print(row)
# Out:
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '0', '.', '.', '.']
# ['.', '.', '.', '.', '.', '0', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '0', '.', '.', '.', '.']
# ['.', '.', '.', '.', '0', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', 'A', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', 'A', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', 'A', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']

# %%
test_char_position_list = find_char(test_map_matrix)

# %%
test_char_position_list
# Out:
# [['0', [(1, 8), (2, 5), (3, 7), (4, 4)]], ['A', [(5, 6), (8, 8), (9, 9)]]]

# %%
test_all_anitnode_list = []
for char in test_char_position_list:
    for i in range(len(char[1])):
        for j in range(i + 1, len(char[1])):
            test_all_anitnode_list += find_antinode(char[1][i], char[1][j], len(test_map_matrix), len(test_map_matrix[0]))

print(len(set(test_all_anitnode_list)))
# Out:
# 14

# %% [markdown]
# The solution below is from: https://github.com/marcodelmastro/AdventOfCode2024/blob/main/Day8.ipynb

# %%
from collections import defaultdict

def read_input_08(filename):
    f = open(filename)
    antennas = defaultdict(list)
    lines = f.readlines()
    for j,l in enumerate(lines):
        for i,c in enumerate(l.strip()):
            if c!=".":
                antennas[c].append((i,j))
    xmax = len(lines[0].strip())
    ymax = len(lines)
    return antennas, xmax, ymax

# %%
from itertools import combinations

def antinodes(a1,a2):
    x1,y1 = a1
    x2,y2 = a2
    return (2.*x2-x1,2.*y2-y1),(2.*x1-x2,2.*y1-y2)

def in_boundaries(a,xmax,ymax):
    xa,ya = a
    return 0<=xa<xmax and 0<=ya<ymax

def find_antinodes(antennas,xmax,ymax):
    antinodes_city = set() # avoid antinode overlaps    
    for freq in antennas.keys():
        for a1,a2 in combinations(antennas[freq],2):
            for an in antinodes(a1,a2):
                if in_boundaries(an,xmax,ymax):
                    antinodes_city.add(an)
    return antinodes_city

def part1(filename):
    antennas, xmax, ymax = read_input_08(filename)
    return len(find_antinodes(antennas,xmax,ymax))

# %%
print("Part 1:",part1("aoc8.txt"))
# Out:
# Part 1: 305
