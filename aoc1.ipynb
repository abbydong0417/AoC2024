# %%
import pandas
# Out:
# <ipython-input-1-38d4b0363d82>:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas

# %%
data=pandas.read_csv('aoc1.txt', header=None, sep=' ')

# %%
data.head()
# Out:
#        0   1   2      3
# 0  80421 NaN NaN  40193
# 1  69841 NaN NaN  31045
# 2  47850 NaN NaN  64065
# 3  63141 NaN NaN  52072
# 4  32908 NaN NaN  83033

# %%
list1=data[0].tolist()

# %%
list2=data[3].tolist()

# %%
list1.sort()

# %%
list1
# Out:
# [10282,
#  10365,
#  10618,
#  10696,
#  10887,
#  10895,
#  10935,
#  11018,
#  11144,
#  11220,
#  11483,
#  11529,
#  11681,
#  11713,
#  11896,
#  12007,
#  12194,
#  12355,
#  12401,
#  12441,
#  12475,
#  12488,
#  12526,
#  12762,
#  12969,
#  12975,
#  12989,
#  13052,
#  13145,
#  13206,
#  13228,
#  13487,
#  13576,
#  13610,
#  13709,
#  13743,
#  13873,
#  13991,
#  14034,
#  14058,
#  14176,
#  14250,
#  14269,
#  14489,
#  14541,
#  14544,
#  14575,
#  14649,
#  14724,
#  14792,
#  14839,
#  14847,
#  14879,
#  14940,
#  15001,
#  15091,
#  15119,
#  15241,
#  15421,
#  15466,
#  15624,
#  15636,
#  15788,
#  15892,
#  15924,
#  16022,
#  16113,
#  16124,
#  16149,
#  16217,
#  16363,
#  16379,
#  16580,
#  16593,
#  16614,
#  16652,
#  16683,
#  16759,
#  16780,
#  16807,
#  16870,
#  16926,
#  16985,
#  17033,
#  17108,
#  17193,
#  17223,
#  17382,
#  17385,
#  17659,
#  17739,
#  17785,
#  17825,
#  17864,
#  17976,
#  18012,
#  18015,
#  18054,
#  18160,
#  18581,
# ...

# %%
list2.sort()

# %%
list2
# Out:
# [10104,
#  10228,
#  10363,
#  10521,
#  10803,
#  10840,
#  10883,
#  11001,
#  11069,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11220,
#  11552,
#  11681,
#  11681,
#  11681,
#  11681,
#  11681,
#  11681,
#  11681,
#  11681,
#  11681,
#  11681,
#  11681,
#  11681,
#  11681,
#  11681,
#  11770,
#  11832,
#  12184,
#  12534,
#  12987,
#  13027,
#  13396,
#  13468,
#  13588,
#  13640,
#  13912,
#  13942,
#  14000,
#  14163,
#  14363,
#  14792,
#  14792,
#  14792,
#  15119,
#  15162,
#  15242,
#  15318,
#  15498,
#  15540,
#  15553,
#  15774,
#  15788,
#  15788,
#  15788,
#  15788,
#  15788,
#  15788,
#  15788,
#  15788,
#  15788,
#  16019,
#  16217,
#  16217,
#  16217,
#  16217,
#  16217,
#  16217,
#  16217,
#  16217,
#  16217,
#  16492,
#  16961,
#  16994,
#  17223,
#  17223,
#  17223,
#  17223,
#  17223,
#  17223,
#  17223,
#  17223,
#  17223,
#  17223,
# ...

# %%
len(list1)
# Out:
# 1000

# %%
len(list2)
# Out:
# 1000

# %%
sumup=0
for i in range(len(list1)):
    delta_dis = abs(list1[i] - list2[i])
    sumup+=delta_dis

# %%
sumup
# Out:
# 2344935

# %%
list1_test=[3,4,2,1,3,3]

# %%
list2_test=[4,3,5,3,9,3]

# %%
sumup=0
for item in list1:
    appear=list2.count(item)
    similar=appear*item
    sumup+=similar

# %%
sumup
# Out:
# 27647262
